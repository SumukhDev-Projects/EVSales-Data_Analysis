# %%
import pandas as pd 

data = {"name" : ["sumukh",  "max", "john"],
"age" :[21 ,24,25],
"salary" :[10000,30000,15000]}

df=pd.DataFrame(data)
print(df)
# Out:
#      name  age  salary
# 0  sumukh   21   10000
# 1     max   24   30000
# 2    john   25   15000

# %%
data=pd.read_excel("/Users/sumukhsharma/Downloads/ESD.xlsx")
#print(data)
print (data.head(10))
# Out:
#      EEID        Full Name                 Job Title  Department  \
# 0  E02387      Emily Davis                Sr. Manger          IT
# 1  E04105    Theodore Dinh       Technical Architect          IT
# 2  E02572     Luna Sanders                  Director     Finance
# 3  E02832  Penelope Jordan  Computer Systems Manager          IT
# 4  E01639        Austin Vo               Sr. Analyst     Finance
# 5  E00644     Joshua Gupta    Account Representative       Sales
# 6  E01550      Ruby Barnes                   Manager          IT
# 7  E04332      Luke Martin                   Analyst     Finance
# 8  E04533    Easton Bailey                   Manager  Accounting
# 9  E03838  Madeline Walker               Sr. Analyst     Finance
#
#             Business Unit  Gender  Ethnicity  Age  Hire Date  Annual Salary  \
# 0  Research & Development  Female      Black   55 2016-04-08         141604
# 1           Manufacturing    Male      Asian   59 1997-11-29          99975
# ...

# %%
print (data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   EEID           1000 non-null   object
#  1   Full Name      1000 non-null   object
#  2   Job Title      1000 non-null   object
#  3   Department     1000 non-null   object
#  4   Business Unit  1000 non-null   object
#  5   Gender         1000 non-null   object
#  6   Ethnicity      1000 non-null   object
#  7   Age            1000 non-null   int64
#  8   Hire Date      1000 non-null   datetime64[ns]
#  9   Annual Salary  1000 non-null   int64
#  10  Bonus %        1000 non-null   float64
#  11  Country        1000 non-null   object
#  12  City           1000 non-null   object
#  13  Exit Date      85 non-null     datetime64[ns]
# dtypes: datetime64[ns](2), float64(1), int64(2), object(9)
# memory usage: 109.5+ KB
# None

# %%
data.describe()
# Out:
#                Age                   Hire Date  Annual Salary      Bonus %  \
# count  1000.000000                        1000    1000.000000  1000.000000
# mean     44.382000  2012-04-07 02:54:14.400000  113217.365000     0.088660
# min      25.000000         1992-01-09 00:00:00   40063.000000     0.000000
# 25%      35.000000         2007-02-14 00:00:00   71430.250000     0.000000
# 50%      45.000000         2014-02-15 12:00:00   96557.000000     0.000000
# 75%      54.000000         2018-06-22 00:00:00  150782.250000     0.150000
# max      65.000000         2021-12-26 00:00:00  258498.000000     0.400000
# std      11.246981                         NaN   53545.985644     0.117856
#
#                            Exit Date
# count                             85
# mean   2016-11-02 18:04:14.117647104
# min              1994-12-18 00:00:00
# 25%              2014-12-25 00:00:00
# 50%              2019-05-23 00:00:00
# 75%              2021-04-09 00:00:00
# ...

# %%
data.isnull().sum()
# Out:
# EEID               0
# Full Name          0
# Job Title          0
# Department         0
# Business Unit      0
# Gender             0
# Ethnicity          0
# Age                0
# Hire Date          0
# Annual Salary      0
# Bonus %            0
# Country            0
# City               0
# Exit Date        915
# dtype: int64

# %%
data=pd.read_csv("/Users/sumukhsharma/Downloads/company1.csv")
print(data)
# Out:
#     EEID      Name gender   salary
# 0  EMP01    ayushi      F      NaN
# 1  EMP02     rohit      M  25000.0
# 2  EMP03  pranjali    NaN  27000.0
# 3  EMP01    ayushi      F  20000.0
# 4  EMP05       NaN      M  25000.0
# 5  EMP06     rohit      M      NaN
# 6  EMP02     rohit      M  25000.0

# %%
print (data["EEID"].duplicated().sum())
# Out:
# 2

# %%
data.drop_duplicates(["EEID"])
# Out:
#     EEID      Name gender   salary
# 0  EMP01    ayushi      F      NaN
# 1  EMP02     rohit      M  25000.0
# 2  EMP03  pranjali    NaN  27000.0
# 4  EMP05       NaN      M  25000.0
# 5  EMP06     rohit      M      NaN

# %%
import numpy as np
print(data.replace(np.nan , "20000"), )
# Out:
#     EEID      Name gender   salary
# 0  EMP01    ayushi      F    20000
# 1  EMP02     rohit      M  25000.0
# 2  EMP03  pranjali  20000  27000.0
# 3  EMP01    ayushi      F  20000.0
# 4  EMP05     20000      M  25000.0
# 5  EMP06     rohit      M    20000
# 6  EMP02     rohit      M  25000.0

# %%
data.salary=data.salary.replace(np.nan, "20000.0")
print (data)
# Out:
#     EEID      Name gender   salary
# 0  EMP01    ayushi      F    20000
# 1  EMP02     rohit      M  25000.0
# 2  EMP03  pranjali    NaN  27000.0
# 3  EMP01    ayushi      F  20000.0
# 4  EMP05       NaN      M  25000.0
# 5  EMP06     rohit      M    20000
# 6  EMP02     rohit      M  25000.0

# %%
data.salary=data.salary.replace(np.nan, "20000.0")
print (data)
# Out:
#     EEID      Name gender   salary
# 0  EMP01    ayushi      F    20000
# 1  EMP02     rohit      M  25000.0
# 2  EMP03  pranjali    NaN  27000.0
# 3  EMP01    ayushi      F  20000.0
# 4  EMP05       NaN      M  25000.0
# 5  EMP06     rohit      M    20000
# 6  EMP02     rohit      M  25000.0

# %%
print(data.replace(np.nan , "not available"), )
# Out:
#     EEID           Name         gender   salary
# 0  EMP01         ayushi              F    20000
# 1  EMP02          rohit              M  25000.0
# 2  EMP03       pranjali  not available  27000.0
# 3  EMP01         ayushi              F  20000.0
# 4  EMP05  not available              M  25000.0
# 5  EMP06          rohit              M    20000
# 6  EMP02          rohit              M  25000.0

# %%
data=pd.read_csv("/Users/sumukhsharma/Downloads/company1.csv")
print(data)
# Out:
#     EEID      Name gender   salary
# 0  EMP01    ayushi      F      NaN
# 1  EMP02     rohit      M  25000.0
# 2  EMP03  pranjali    NaN  27000.0
# 3  EMP01    ayushi      F  20000.0
# 4  EMP05       NaN      M  25000.0
# 5  EMP06     rohit      M      NaN
# 6  EMP02     rohit      M  25000.0

# %%
print(data["salary"].mean())
# Out:
# 24400.0

# %%
data.salary=data.salary.replace(np.nan,"24400.0")
print(data)
# Out:
#     EEID      Name gender   salary
# 0  EMP01    ayushi      F    24400
# 1  EMP02     rohit      M  25000.0
# 2  EMP03  pranjali    NaN  27000.0
# 3  EMP01    ayushi      F  20000.0
# 4  EMP05       NaN      M  25000.0
# 5  EMP06     rohit      M    24400
# 6  EMP02     rohit      M  25000.0

# %%
df=pd.read_excel("/Users/sumukhsharma/Downloads/ESD.xlsx")
df.loc[(df["Annual Salary"]< 90000),"getbonus" ]= "yes"
df.loc[(df["Bonus %"]> 90000,"getbonus" )]= "no bonus"
print (df.head(10))
# Out:
#      EEID        Full Name                 Job Title  Department  \
# 0  E02387      Emily Davis                Sr. Manger          IT
# 1  E04105    Theodore Dinh       Technical Architect          IT
# 2  E02572     Luna Sanders                  Director     Finance
# 3  E02832  Penelope Jordan  Computer Systems Manager          IT
# 4  E01639        Austin Vo               Sr. Analyst     Finance
# 5  E00644     Joshua Gupta    Account Representative       Sales
# 6  E01550      Ruby Barnes                   Manager          IT
# 7  E04332      Luke Martin                   Analyst     Finance
# 8  E04533    Easton Bailey                   Manager  Accounting
# 9  E03838  Madeline Walker               Sr. Analyst     Finance
#
#             Business Unit  Gender  Ethnicity  Age  Hire Date  Annual Salary  \
# 0  Research & Development  Female      Black   55 2016-04-08         141604
# 1           Manufacturing    Male      Asian   59 1997-11-29          99975
# ...

# %%
data={"months": ["january" ,"february", "march", "april" ]}
a=pd.DataFrame(data)
#print(a)

def extract (value):
    return value[0:3]

a ["short months"] = a ["months"].map(extract)
print (a)
# Out:
#      months short months
# 0   january          jan
# 1  february          feb
# 2     march          mar
# 3     april          apr

# %%
df=pd.read_excel("/Users/sumukhsharma/Downloads/ESD.xlsx")
print (df)
# Out:
#        EEID        Full Name                 Job Title  Department  \
# 0    E02387      Emily Davis                Sr. Manger          IT
# 1    E04105    Theodore Dinh       Technical Architect          IT
# 2    E02572     Luna Sanders                  Director     Finance
# 3    E02832  Penelope Jordan  Computer Systems Manager          IT
# 4    E01639        Austin Vo               Sr. Analyst     Finance
# ..      ...              ...                       ...         ...
# 995  E03094     Wesley Young               Sr. Analyst   Marketing
# 996  E01909     Lillian Khan                   Analyst     Finance
# 997  E04398      Oliver Yang                  Director   Marketing
# 998  E02521      Lily Nguyen               Sr. Analyst     Finance
# 999  E03545      Sofia Cheng            Vice President  Accounting
#
#               Business Unit  Gender  Ethnicity  Age  Hire Date  Annual Salary  \
# 0    Research & Development  Female      Black   55 2016-04-08         141604
# ...

# %%
gp=df.groupby( ["Country"]).agg({"Age": "mean" })
print (gp)
# Out:
#                      Age
# Country
# Brazil         43.654676
# China          45.389908
# United States  44.197512

# %%
import matplotlib.pyplot as plt

y= [98,99,97,67,88,24]
x = ["part 1", "part 2" ,"part 3", "part 4" ,"part 5", "part 6" ]
color=["red" ,"blue" ,"green" ,"yellow", "orange", "black"]
plt.bar (x,y, color= color)
plt.xlabel("part of harry potter movies", fontsize = 18)
plt.ylabel("popularity in percentage",fontsize = 18)
plt.title("popularity of different parts of harry potter movies" ,fontsize = 22)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

data= pd.read_excel("/Users/sumukhsharma/Downloads/expense3.xlsx")
df= pd.DataFrame(data)

plt.bar(df["Payment Mode"], df["Amount"])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[90], line 7
#       4 data= pd.read_excel("/Users/sumukhsharma/Downloads/expense3.xlsx")
#       5 df= pd.DataFrame(data)
# ----> 7 plt.bar(df["Payment Mode"], df["Amount"])
#       8 plt.show()
#
# File ~/Python/env/lib/python3.12/site-packages/matplotlib/pyplot.py:2956, in bar(x, height, width, bottom, align, data, **kwargs)
#    2945 @_copy_docstring_and_deprecators(Axes.bar)
#    2946 def bar(
#    2947     x: float | ArrayLike,
#    (...)
#    2954     **kwargs,
#    2955 ) -> BarContainer:
# -> 2956     return gca().bar(
#    2957         x,
#    2958         height,
#    2959         width=width,
#    2960         bottom=bottom,
#    2961         align=align,
#    2962         **({"data": data} if data is not None else {}),
#    2963         **kwargs,
#    2964     )
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

data= pd.read_excel("/Users/sumukhsharma/Downloads/expense3.xlsx")
df= pd.DataFrame(data)

print (df)
# Out:
#          Date    Category       Sub-Category   Amount Payment Mode
# 0  2023-01-01     Grocery             Grocery      30         Cash
# 1  2023-01-02        Food          Restaurant     890          UPI
# 2  2023-01-04         123              Zomato     257          NaN
# 3  2023-01-06  Essentials               Diary     120          UPI
# 4  2023-01-06  Essentials             Perfume    1500         Cash
# 5  2023-01-09     Grocery  Fruits and Veggies     456         Cash
# 6  2023-01-10       Bills          House Rent   16000          UPI
# 7  2023-01-10     Grocery      Tomato KetchUp      70          UPI
# 8  2023-01-12        Food                Chai      15          UPI
# 9  2023-01-15  Essentials      Salt and Sugar      50          NaN
# 10 2023-01-17     Grocery           Chocolate     100          UPI
# 11 2023-01-17        Food          Restaurant     780         Card
# 12 2023-01-18  Essentials            Food Oil     120          NaN
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

data= pd.read_excel("/Users/sumukhsharma/Downloads/expense3.xlsx")
df= pd.DataFrame(data)
print(df)
group_by = df.groupby("Payment Mode")["Amount"].sum()
print(group_by)
plt.bar(group_by.index, group_by.values )
plt.xlabel("payment methods")
plt.ylabel(" amount ")
plt.title("amount based on the payment mode ")
plt.show()
#plt.bar(df["Payment Mode"], df["Amount"])
#plt.show()
# Out:
#          Date    Category       Sub-Category   Amount Payment Mode
# 0  2023-01-01     Grocery             Grocery      30         Cash
# 1  2023-01-02        Food          Restaurant     890          UPI
# 2  2023-01-04         123              Zomato     257          NaN
# 3  2023-01-06  Essentials               Diary     120          UPI
# 4  2023-01-06  Essentials             Perfume    1500         Cash
# 5  2023-01-09     Grocery  Fruits and Veggies     456         Cash
# 6  2023-01-10       Bills          House Rent   16000          UPI
# 7  2023-01-10     Grocery      Tomato KetchUp      70          UPI
# 8  2023-01-12        Food                Chai      15          UPI
# 9  2023-01-15  Essentials      Salt and Sugar      50          NaN
# 10 2023-01-17     Grocery           Chocolate     100          UPI
# 11 2023-01-17        Food          Restaurant     780         Card
# 12 2023-01-18  Essentials            Food Oil     120          NaN
# ...

# %%
x = ["day 1", "day 2", "day 3" ,"day 4" ,"day 5" ]
y = [12,53,34,45,16]
y1=[23,34,14,35,10]
plt.plot(x,y, marker="o", ls= "--", color="r", label= "week1 ")
plt.plot(x,y1, marker="D", ls= "-", color="g", label = "week 2 ")
plt.legend()
plt.show()

# %%
data= pd.read_excel("/Users/sumukhsharma/Downloads/expense3.xlsx")
df= pd.DataFrame(data)

group_by = df.groupby("Category")["Amount"].sum()
print(group_by)

plt.plot(group_by.index, group_by.values)
print(df)
plt.show()
# Out:
# Category
# 123             257
# Bills         18724
# Clothes        2890
# Essentials     4485
# Food           2765
# Grocery        1028
# Name: Amount, dtype: int64
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[124], line 7
#       4 group_by = df.groupby("Category")["Amount"].sum()
#       5 print(group_by)
# ----> 7 plt.plot(group_by.index, group_by.values)
#       8 print(df)
#       9 plt.show()
#
# File ~/Python/env/lib/python3.12/site-packages/matplotlib/pyplot.py:3794, in plot(scalex, scaley, data, *args, **kwargs)
#    3786 @_copy_docstring_and_deprecators(Axes.plot)
#    3787 def plot(
#    3788     *args: float | ArrayLike | str,
#    (...)
#    3792     **kwargs,
#    3793 ) -> list[Line2D]:
# -> 3794     return gca().plot(
#    3795         *args,
#    3796         scalex=scalex,
#    3797         scaley=scaley,
# ...

# %%
import numpy as np

x= np.random.randint(1,10,50)
y= np.random.randint(10,100,50)
color=np.random.randint(10,100,50)

plt.scatter(x,y, marker="*",cmap= "hot" , c = color)
plt.colorbar()
plt.show()

# %%
df=pd.read_excel("/Users/sumukhsharma/Downloads/ESD.xlsx")
print (df)
plt.scatter(df["Age"], df["EEID"])
plt.show()
# Out:
#        EEID        Full Name                 Job Title  Department  \
# 0    E02387      Emily Davis                Sr. Manger          IT
# 1    E04105    Theodore Dinh       Technical Architect          IT
# 2    E02572     Luna Sanders                  Director     Finance
# 3    E02832  Penelope Jordan  Computer Systems Manager          IT
# 4    E01639        Austin Vo               Sr. Analyst     Finance
# ..      ...              ...                       ...         ...
# 995  E03094     Wesley Young               Sr. Analyst   Marketing
# 996  E01909     Lillian Khan                   Analyst     Finance
# 997  E04398      Oliver Yang                  Director   Marketing
# 998  E02521      Lily Nguyen               Sr. Analyst     Finance
# 999  E03545      Sofia Cheng            Vice President  Accounting
#
#               Business Unit  Gender  Ethnicity  Age  Hire Date  Annual Salary  \
# 0    Research & Development  Female      Black   55 2016-04-08         141604
# ...

# %%
brands= [ "apple", "samsung" ,"redmi", "oppo", "vivo"]
x = [65,45,35,45,24]
ex = [0,0,0,0,0.1]
plt.pie(x, labels = brands, explode = ex, autopct="%.2f")
plt.show()

# %%
data= pd.read_excel("/Users/sumukhsharma/Downloads/expense3.xlsx")
df=pd.DataFrame(data)

group_by=df.groupby("Payment Mode")["Amount"].sum()
print(group_by)
ex= [0.2,0,0]
plt.pie(group_by.values, labels= group_by.index, autopct="%.2f",explode= ex)
print(df)
# Out:
# Payment Mode
# Card      780
# Cash     4637
# UPI     23305
# Name: Amount, dtype: int64
#          Date    Category       Sub-Category   Amount Payment Mode
# 0  2023-01-01     Grocery             Grocery      30         Cash
# 1  2023-01-02        Food          Restaurant     890          UPI
# 2  2023-01-04         123              Zomato     257          NaN
# 3  2023-01-06  Essentials               Diary     120          UPI
# 4  2023-01-06  Essentials             Perfume    1500         Cash
# 5  2023-01-09     Grocery  Fruits and Veggies     456         Cash
# 6  2023-01-10       Bills          House Rent   16000          UPI
# 7  2023-01-10     Grocery      Tomato KetchUp      70          UPI
# 8  2023-01-12        Food                Chai      15          UPI
# 9  2023-01-15  Essentials      Salt and Sugar      50          NaN
# 10 2023-01-17     Grocery           Chocolate     100          UPI
# 11 2023-01-17        Food          Restaurant     780         Card
# ...

# %%
df=pd.read_excel("/Users/sumukhsharma/Downloads/ESD.xlsx")
df=pd.DataFrame(data)

print(df)
#df2=(df.head(50))

#plt.stem(df2["Age"])
#plt.show()
# Out:
#          Date    Category       Sub-Category   Amount Payment Mode
# 0  2023-01-01     Grocery             Grocery      30         Cash
# 1  2023-01-02        Food          Restaurant     890          UPI
# 2  2023-01-04         123              Zomato     257          NaN
# 3  2023-01-06  Essentials               Diary     120          UPI
# 4  2023-01-06  Essentials             Perfume    1500         Cash
# 5  2023-01-09     Grocery  Fruits and Veggies     456         Cash
# 6  2023-01-10       Bills          House Rent   16000          UPI
# 7  2023-01-10     Grocery      Tomato KetchUp      70          UPI
# 8  2023-01-12        Food                Chai      15          UPI
# 9  2023-01-15  Essentials      Salt and Sugar      50          NaN
# 10 2023-01-17     Grocery           Chocolate     100          UPI
# 11 2023-01-17        Food          Restaurant     780         Card
# 12 2023-01-18  Essentials            Food Oil     120          NaN
# ...

# %%
df=pd.read_excel("/Users/sumukhsharma/Downloads/ESD.xlsx")
print (df)

df2 = (df.head(50))
plt.stem(df2["Age"])
plt.plot (df2["Age"])
plt.show()
# Out:
#        EEID        Full Name                 Job Title  Department  \
# 0    E02387      Emily Davis                Sr. Manger          IT
# 1    E04105    Theodore Dinh       Technical Architect          IT
# 2    E02572     Luna Sanders                  Director     Finance
# 3    E02832  Penelope Jordan  Computer Systems Manager          IT
# 4    E01639        Austin Vo               Sr. Analyst     Finance
# ..      ...              ...                       ...         ...
# 995  E03094     Wesley Young               Sr. Analyst   Marketing
# 996  E01909     Lillian Khan                   Analyst     Finance
# 997  E04398      Oliver Yang                  Director   Marketing
# 998  E02521      Lily Nguyen               Sr. Analyst     Finance
# 999  E03545      Sofia Cheng            Vice President  Accounting
#
#               Business Unit  Gender  Ethnicity  Age  Hire Date  Annual Salary  \
# 0    Research & Development  Female      Black   55 2016-04-08         141604
# ...

# %%
import matplotlib.pyplot as plt
days =[1,2,3,4,5]

NOP1= [100 ,400 ,300 ,500,350]
NOP2= [150 ,460 ,370 ,510,310]
NOP3= [120 ,430 ,390 ,470,300]

plt.stackplot(days, NOP1, NOP2, NOP3 , colors= ["pink", "red", "blue"], labels = ["week1", "week2 ", "week3"])
plt.legend()
plt.show()
